# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load the raw data
df = pd.read_excel(r'C:\Users\tiesi\Class D\Aruodas Analytical work part 1\Data.xlsx', index_col=0)

# %%
df.describe().transpose()
# Out:
#                       count           mean            std     min      25%  \
# is_new_project      86269.0       0.872005       0.334086     0.0      1.0
# reserved            86269.0       0.865386       0.341313     0.0      1.0
# price_change        86269.0       0.034887       1.862727    -0.9      0.0
# is_auction          86269.0       0.866186       0.340454     0.0      1.0
# nr_stars            86269.0       0.414471       0.895798     0.0      0.0
# year                86269.0    1996.365983      28.175363  1860.0   1977.0
# total_price         86269.0  135226.900926  121391.460171   420.0  71900.0
# price_sq_m          86269.0    2028.617847     862.427039     6.0   1444.0
# rounded_price_sq_m  86269.0    2030.262319     863.637998     0.0   1400.0
# nr_rooms            86269.0       2.491637       1.060680     1.0      2.0
# space_sq_m          86269.0      63.794534      38.088261    10.0     42.0
# ...

# %%
df.isnull().any().any(), df.shape
# Out:
# (False, (86269, 19))

# %%
df.head()
# Out:
#      log_date          street  is_new_project  reserved  price_change  \
# ID
# 1  2020-04-09  A. Goštauto g.               0         0        -0.023
# 2  2020-04-09  A. Goštauto g.               0         0         0.000
# 3  2020-04-09  A. Goštauto g.               0         1         0.000
# 4  2020-04-09    A. Jakšto g.               0         0         0.000
# 5  2020-04-09    A. Jakšto g.               0         0         0.000
#
#     is_auction  nr_stars  year  total_price  price_sq_m  rounded_price_sq_m  \
# ID
# 1            0         0  1957       122000        3167                3200
# 2            0         0  1960       169000        2192                2200
# 3            0         1  1955       156000        2889                2900
# 4            0         0  2006       147000        3642                3600
# 5            0         0  2006       468880        4000                4000
#
# ...

# %%
df[:10][['price_sq_m', 'price_change']]
# Out:
#     price_sq_m  price_change
# ID
# 1         3167        -0.023
# 2         2192         0.000
# 3         2889         0.000
# 4         3642         0.000
# 5         4000         0.000
# 6         2685         0.000
# 7         3030         0.000
# 8         2685         0.000
# 9          797         0.014
# 10        2685         0.036

# %%
df['price_sq_m'].corr(df['total_price'])
# Out:
# 0.679342786464089

# %%
#Potential features
potentialFeatures = ['is_new_project', 'reserved', 'price_change', 'is_auction', 'nr_stars', 'year', 'total_price',
                    'nr_rooms', 'space_sq_m', 'floor', 'nr_floors', 'state', 'type', 'size_bucket', 'price_sq_m']

# %%
# check how the features are correlated with the price  sq m
for f in potentialFeatures:
    related = df['price_sq_m'].corr(df[f])
    print("%s: %f" % (f,related))
# Out:
# is_new_project: -0.006192
# reserved: -0.005949
# price_change: -0.008132
# is_auction: -0.016659
# nr_stars: -0.015238
# year: 0.132438
# total_price: 0.679343
# nr_rooms: 0.102678
# space_sq_m: 0.176941
# floor: 0.086276
# nr_floors: 0.010650
# state: 0.015822
# type: nan
# size_bucket: 0.189488
# price_sq_m: 1.000000
